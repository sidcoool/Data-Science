# %%
from urllib.request import urlopen

# %%
api_url="https://samples.openweathermap.org/data/2.5/weather?q=London,uk&appid=b6907d289e10d714a6e88b30761fae22"
url_request=urlopen(api_url)
print(url_request)

# %%
api_data=url_request.read()
print(api_data)
# Out:
# b'{"coord":{"lon":-0.13,"lat":51.51},"weather":[{"id":300,"main":"Drizzle","description":"light intensity drizzle","icon":"09d"}],"base":"stations","main":{"temp":280.32,"pressure":1012,"humidity":81,"temp_min":279.15,"temp_max":281.15},"visibility":10000,"wind":{"speed":4.1,"deg":80},"clouds":{"all":90},"dt":1485789600,"sys":{"type":1,"id":5091,"message":0.0103,"country":"GB","sunrise":1485762037,"sunset":1485794875},"id":2643743,"name":"London","cod":200}'

# %%
import json
json_data=json.loads(api_data)
print(json_data)
# Out:
# {'coord': {'lon': -0.13, 'lat': 51.51}, 'weather': [{'id': 300, 'main': 'Drizzle', 'description': 'light intensity drizzle', 'icon': '09d'}], 'base': 'stations', 'main': {'temp': 280.32, 'pressure': 1012, 'humidity': 81, 'temp_min': 279.15, 'temp_max': 281.15}, 'visibility': 10000, 'wind': {'speed': 4.1, 'deg': 80}, 'clouds': {'all': 90}, 'dt': 1485789600, 'sys': {'type': 1, 'id': 5091, 'message': 0.0103, 'country': 'GB', 'sunrise': 1485762037, 'sunset': 1485794875}, 'id': 2643743, 'name': 'London', 'cod': 200}

# %%
print(json_data['main'])
# Out:
# {'temp': 280.32, 'pressure': 1012, 'humidity': 81, 'temp_min': 279.15, 'temp_max': 281.15}

# %%
json_string=json.dumps(json_data)
print(json_string)
# Out:
# {"coord": {"lon": -0.13, "lat": 51.51}, "weather": [{"id": 300, "main": "Drizzle", "description": "light intensity drizzle", "icon": "09d"}], "base": "stations", "main": {"temp": 280.32, "pressure": 1012, "humidity": 81, "temp_min": 279.15, "temp_max": 281.15}, "visibility": 10000, "wind": {"speed": 4.1, "deg": 80}, "clouds": {"all": 90}, "dt": 1485789600, "sys": {"type": 1, "id": 5091, "message": 0.0103, "country": "GB", "sunrise": 1485762037, "sunset": 1485794875}, "id": 2643743, "name": "London", "cod": 200}

# %% [markdown]
# ## google apis

# %%
# !pip install requests
# Out:
# ...
# You are using pip version 19.0.3, however version 19.2.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import requests

# %%
url="https://maps.googleapis.com/maps/api/geocode/json?"

# %%
ur_address=input()
# Out:
# grand omaxe

# %%
parameters={"address":ur_address,"key":"AIzaSyDxpzAOiOie2lqiUfMhWegOvmbKH25TNlE"}
r=requests.get(url,params=parameters)

# %%
r.url
# Out:
# 'https://maps.googleapis.com/maps/api/geocode/json?address=grand+omaxe&key=AIzaSyDxpzAOiOie2lqiUfMhWegOvmbKH25TNlE'

# %%
print(r.content.decode("Utf-8"))
# Out:
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "Noida Road",
#                "short_name" : "Noida Rd",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Block C",
#                "short_name" : "Block C",
#                "types" : [ "political", "sublocality", "sublocality_level_2" ]
#             },
#             {
#                "long_name" : "Sector 93",
#                "short_name" : "Sector 93",
#                "types" : [ "political", "sublocality", "sublocality_level_1" ]
#             },
#             {
#                "long_name" : "Noida",
#                "short_name" : "Noida",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Gautam Buddh Nagar",
#                "short_name" : "Gautam Buddh Nagar",
#                "types" : [ "administrative_area_level_2", "political" ]
# ...

# %%
print(type(r.content.decode("Utf-8")))
# Out:
# <class 'str'>

# %%
data_String=r.content.decode("Utf-8")
print(data_String)
# Out:
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "Noida Road",
#                "short_name" : "Noida Rd",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Block C",
#                "short_name" : "Block C",
#                "types" : [ "political", "sublocality", "sublocality_level_2" ]
#             },
#             {
#                "long_name" : "Sector 93",
#                "short_name" : "Sector 93",
#                "types" : [ "political", "sublocality", "sublocality_level_1" ]
#             },
#             {
#                "long_name" : "Noida",
#                "short_name" : "Noida",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Gautam Buddh Nagar",
#                "short_name" : "Gautam Buddh Nagar",
#                "types" : [ "administrative_area_level_2", "political" ]
# ...

# %%
import json

# %%
data_dict=json.loads(data_String)
dict2=data_dict["results"][0]

# %%
print(dict2["address_components"][2])
# Out:
# {'long_name': 'Sector 93', 'short_name': 'Sector 93', 'types': ['political', 'sublocality', 'sublocality_level_1']}

# %% [markdown]
# ## facebook api

# %%
url="http://graph.facebook.com/100003268478465/picture?type=large"

# %%
r=requests.get(url)

# %%
print(r.content)
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x02\x00\x00\x01\x00\x01\x00\x00\xff\xed\x00\x9cPhotoshop 3.0\x008BIM\x04\x04\x00\x00\x00\x00\x00\x80\x1c\x02g\x00\x14b295VZVmXpRiJumLDPCV\x1c\x02(\x00bFBMD01000ac2030000e2060000480b0000ba0c00005d0e00002b1200005118000005190000911a0000271c000025260000\xff\xe2\x02\x1cICC_PROFILE\x00\x01\x01\x00\x00\x02\x0clcms\x02\x10\x00\x00mntrRGB XYZ \x07\xdc\x00\x01\x00\x19\x00\x03\x00)\x009acspAPPL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-lcms\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\ndesc\x00\x00\x00\xfc\x00\x00\x00^cprt\x00\x00\x01\\\x00\x00\x00\x0bwtpt\x00\x00\x01h\x00\x00\x00\x14bkpt\x00\x00\x01|\x00\x00\x00\x14rXYZ\x00\x00\x01\x90\x00\x00\x00\x14gXYZ\x00\x00\x01\xa4\x00\x00\x00\x14bXYZ\x00\x00\x01\xb8\x00\x00\x00\
# ...

# %%
with open("facebook_dp.jpg","wb") as f:
    f.write(r.content)
